# %% [markdown]
# <a href="https://colab.research.google.com/github/KdlsMH/20204451_Digital_Image_Processing_-/blob/main/Ch02_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as pit

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Images/lena256.jpg')
print(img.shape)
cv2_imshow(img)
# Out:
# (256, 256, 3)
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(RGB_img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
pit.imshow(RGB_img)
pit.show()

# %%
R_img, G_img, B_img = cv2.split(RGB_img)

# %%
print(R_img.shape)
print(G_img.shape)
print(B_img.shape)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)

# %%
cv2_imshow(R_img)
# Out:
# <PIL.Image.Image image mode=L size=256x256>

# %%
CImg = RGB_img

# %%
CImg[:,:,0] = R_img
CImg[:,:,1] = R_img
CImg[:,:,2] = R_img

# %%
pit.imshow(CImg)
pit.show()

# %%
CImg[:,:,0] = G_img
CImg[:,:,1] = G_img
CImg[:,:,2] = G_img

# %%
pit.imshow(CImg)
pit.show()

# %%
CImg[:,:,0] = G_img
CImg[:,:,1] = G_img
CImg[:,:,2] = G_img

# %%
pit.imshow(CImg)
pit.show()

# %%
HSV_img = cv2.cvtColor(RGB_img, cv2.COLOR_RGB2HSV)

# %%
cv2_imshow(HSV_img)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
H_img, S_img, V_img = cv2.split(RGB_img)
CImg[:,:,0] = V_img
CImg[:,:,1] = V_img
CImg[:,:,2] = V_img
pit.imshow(CImg)
pit.show()
