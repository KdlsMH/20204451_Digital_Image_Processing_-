# %%
# !python --version
# Out:
# Python 3.12.11

# %%
from google.colab import drive
from google.colab.patches import cv2_imshow
import cv2
import numpy as np
import matplotlib.pyplot as pit

# %%
drive.mount ('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = cv2.imread('/content/gdrive/My Drive/IP/Ch_01/jyr01.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=530x691>

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
pit.imshow(RGB_img)

# %%
print(img.shape)
# Out:
# (691, 530, 3)
